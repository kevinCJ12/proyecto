# %%
import pandas as pd
df=pd.read_csv('windows.csv')
print(df.rolling(3).sum())
# Out:
#    valor
# 0    NaN
# 1    NaN
# 2    3.0
# 3    6.0

# %%
df['rolling'] = df.rolling(window=3).sum()

# %%
df['rolling'] = df['valor'].rolling(window=2).sum()
