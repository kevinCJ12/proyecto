# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv("/content/drive/My Drive/pandas/dataset.csv", index_col="id")

df.tail(5)
df.describe()
df.columns
df.head(5)

# %%
df_filtrado = df.dropna()  
df_filtrado.head(5)

df_llenado = df.fillna(0)
df = df.fillna({"retweets": 0, "mentions": -1})
df_llenado.head()
df.head()

# %%
df["favorites"] 
df["full_text"]
df[["favorites", "full_text"]]

df.loc[0] 
df.loc[0:2]
df.loc[[0, 1, 2]] 

df.loc[[0, 1, 2], ["favorites"]]

df.loc[:, ["favorites", "full_text"]]

df.loc[1:3, ["favorites", "full_text", "mentions"]]

df[df["favorites"] > 400]
df[(df["favorites"] > 400) & (df["mentions"] > 20)]
df[df["full_text"].str.contains("Programming")]

# %%
import random

def calcularGanancias(retweets):
    return retweets * random.randint(3, 5)
df["ganancias"] = df["retweets"].apply(calcularGanancias)
df.head(10)

def popularidad(fila):
    return fila["followees"]/fila["followers"]

df["popularidad"] = df.apply(popularidad, axis=1)
df.head(10)
# Out:
#                                                 full_text  ...  popularidad
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...     0.663239
# 183722                Today we commemorate and MNML Case.  ...     1.855397
# 183723       Today we have reached US$6.55 Billion TT$44…  ...    10.750000
# 183724  Faking It by Joel Atwell. Written by Other cou...  ...     1.138554
# 183725                                    Welcome back! 🙌  ...    10.750000
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!  ...     1.855397
# 183727                                 80's & friends! ✈️  ...     0.663239
# 183728  Thank you guess how did I feel somewhat offend...  ...    10.750000
# 183729        OnePlus 8 international giveaway classifies  ...    10.750000
# 183730                Here it is.. Retweet this desperate  ...     1.855397
#
# [10 rows x 10 columns]

# %%
df.groupby("country").mean()

df.groupby("country").agg({
    "followers": 'sum',
    "mentions": 'mean',
    "retweets": 'max'
})

grouped = df.groupby("country").agg({
    "followers": 'sum',
    "mentions": 'mean',
    "retweets": 'max'
})
grouped[grouped["followers"] > 5000]
# Out:
#          followers  mentions  retweets
# country
# BRASIL      6166.0      19.6     145.0

# %%
import matplotlib.pyplot as plt
grouped["followers"].plot()
plt.show()

# %%
grouped[["followers"]].plot(kind="bar")
plt.show()

# %%
df.plot(kind="scatter", x ="favorites", y ="retweets")
plt.show()

# %%
grouped.to_csv("./salida.csv")

# %%
datos = [
    {
        "columna1": 1,
        "columna2": 93
    },
    {
        "columna1": 3,
        "columna2": 94
    }
]

df2 = pd.DataFrame(datos)
df2
# Out:
#    columna1  columna2
# 0         1        93
# 1         3        94

# %%
from classifier import SentimentClassifier 

clf = SentimentClassifier()

# %%
x = "Esta muy buena esa pelicula"
y = "Que horrible comida!!!"
z = "Tuve una experiencia netural"

# %%
clf.predict(x)

# %%
clf.predict(y)

# %%
clf.predict(z)

# %%
print("Este es el bloque 1")
x = 10

print ("Este es el bloque 2")
print ("Variable X:", x)
# Out:
# Este es el bloque 1
# Este es el bloque 2
# Variable X: 10
